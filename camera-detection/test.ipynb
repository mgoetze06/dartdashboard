# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = cv2.imread("cam1.jpg")

# %%
cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/boris/.local/lib/python3.10/site-packages/cv2/qt/plugins"

# %%
print(img.shape)
print(img[0])
print(img[1])
print(img[2])

plt.imshow(img[...,0])
# Out:
# (1080, 1920, 3)
# [[ 84 102  95]
#  [ 84 102  95]
#  [ 84 102  95]
#  ...
#  [  1   1   1]
#  [  2   2   2]
#  [  3   3   3]]
# [[ 82 101  92]
#  [ 82 101  92]
#  [ 82 101  92]
#  ...
#  [  1   1   1]
#  [  1   1   1]
#  [  1   1   1]]
# [[ 82 102  89]
#  [ 82 102  89]
#  [ 83 101  88]
#  ...
#  [  1   1   1]
#  [  1   1   1]
#  [  1   1   1]]

# %%
plt.imshow(img[...,1])

# %%
plt.imshow(img[...,2])

# %%
test = img[...,2] - img[...,1]
plt.imshow(test)
